# %% [markdown]
# # Desafio Cartão de credito
# ## Porque os clientes estão desistindo da compra
# - Passo 1: Importar base de dados de https://www.kaggle.com/sakshigoyal7/credit-card-customers
# - Passo 2: Tratar base de dados
# - Passo 3: Visualizar dados
# - Passo 4: Construir uma analise com as soluções para isso

# %% [markdown]
# ### Passo 1 :

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
db = pd.read_csv(r'C:\Users\vinis\Downloads\archive\BankChurners.csv')
print(db.head())
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
print(db.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %%
print(db.describe())
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %%
print(db.shape)
# Out:
# (10127, 23)

# %% [markdown]
# ### Passo 2:

# %%
db = db.drop(columns=['CLIENTNUM'])

# %%
print(db.head())
# Out:
#       Attrition_Flag  Customer_Age Gender  Dependent_count Education_Level  \
# 0  Existing Customer            45      M                3     High School
# 1  Existing Customer            49      F                5        Graduate
# 2  Existing Customer            51      M                3        Graduate
# 3  Existing Customer            40      F                4     High School
# 4  Existing Customer            40      M                3      Uneducated
#
#   Marital_Status Income_Category Card_Category  Months_on_book  \
# 0        Married     $60K - $80K          Blue              39
# 1         Single  Less than $40K          Blue              44
# 2        Married    $80K - $120K          Blue              36
# 3        Unknown  Less than $40K          Blue              34
# 4        Married     $60K - $80K          Blue              21
#
#    Total_Relationship_Count  ...  Credit_Limit  Total_Revolving_Bal  \
# ...

# %%
print(db.describe().round(2))
# Out:
#        Customer_Age  Dependent_count  Months_on_book  \
# count      10127.00         10127.00        10127.00
# mean          46.33             2.35           35.93
# std            8.02             1.30            7.99
# min           26.00             0.00           13.00
# 25%           41.00             1.00           31.00
# 50%           46.00             2.00           36.00
# 75%           52.00             3.00           40.00
# max           73.00             5.00           56.00
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count                  10127.00                10127.00
# mean                       3.81                    2.34
# std                        1.55                    1.01
# min                        1.00                    0.00
# 25%                        3.00                    2.00
# 50%                        4.00                    2.00
# 75%                        5.00                    3.00
# ...

# %%
display(db.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 22 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   Attrition_Flag                                                                                                                      10127 non-null  object
#  1   Customer_Age                                                                                                                        10127 non-null  int64
#  2   Gender                                                                                                                              10127 non-null  object
# ...

# %%
qte = db['Attrition_Flag'].value_counts()
qte_perc  =db['Attrition_Flag'].value_counts(normalize=True)
print(f"""Valores totais:
{qte}

Valores percentuais:
{qte_perc}""")
# Out:
# Valores totais:
# Existing Customer    8500
# Attrited Customer    1627
# Name: Attrition_Flag, dtype: int64
#
# Valores percentuais:
# Existing Customer    0.83934
# Attrited Customer    0.16066
# Name: Attrition_Flag, dtype: float64

# %% [markdown]
# ### Passo 3:

# %%
for coluna in db:
    if coluna != 'Attrition_Flag':
        I_cliente = db[coluna].loc[db['Attrition_Flag'] =='Existing Customer' ]
        I_des = db[coluna].loc[db['Attrition_Flag'] !='Existing Customer' ]
        plt.hist(I_cliente, color='skyblue', label='Clientes')
        plt.hist(I_des, label='Desistentes')
        plt.xlabel(coluna)
        plt.legend()
        plt.show()

# %% [markdown]
# ### Passo 4:

# %% [markdown]
# #### De acordo com nossa analise:
# * A maioria dos clientes que cancelam entraram em contato varias vezes com a empresa
# * Quanto menor o credito maior o cancelamento
# * Quando menos transações faz, mais cancela
# * Quanto menos serviços mais cancela
# * A maioria dos cancelados está no cartão BLUE(menor impacto porém significativo)
